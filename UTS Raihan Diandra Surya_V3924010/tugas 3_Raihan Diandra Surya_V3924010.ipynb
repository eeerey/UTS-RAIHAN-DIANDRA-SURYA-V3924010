# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "D:/Downloads/data_pasien2.csv" # Sesuaikan dengan lokasi file Anda
df = pd.read_csv(file_path, encoding = "windows-1252", delimiter=";")

# Tampilkan beberapa baris pertama untuk cek data
print(df.head())

# a. Probabilitas benar-benar sakit jika hasil tes positif
positif = df[df['Hasil_Tes'] == 'Positif']
sakitPositif = positif[positif['Menderita_Penyakit'] == 'Ya']
probSakitTesPositif = len(sakitPositif) / len(positif)

# b. Probabilitas tidak sakit jika hasil tes negatif
negatif = df[df['Hasil_Tes'] == 'Negatif']
tidakSakitNegatif = negatif[negatif['Menderita_Penyakit'] == 'Tidak']
tidakSakitTesNegatif = len(tidakSakitNegatif) / len(negatif)

# Tampilkan hasil
print("\nHasil Perhitungan:")
print(f"a. Probabilitas pasien Benar sakit jika hasil tesnya POSITIF: {probSakitTesPositif:.2f}")
print(f"b. Probabilitas pasien Tidak sakit jika hasil tesnya NEGATIF: {tidakSakitTesNegatif:.2f}")

# c. Visualisasi distribusi hasil tes dan status penyakit
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Hasil_Tes', hue='Menderita_Penyakit', palette='Set2')
plt.title("Distribusi Hasil Tes dan Status Penyakit")
plt.xlabel("Hasil Tes")
plt.ylabel("Jumlah Pasien")
plt.legend(title="Menderita Penyakit")
plt.grid(True)
plt.show()
# Out:
#      Pasien Hasil_Tes Menderita_Penyakit
# 0  Pasien_1   Positif                 Ya
# 1  Pasien_2   Positif                 Ya
# 2  Pasien_3   Positif                 Ya
# 3  Pasien_4   Positif                 Ya
# 4  Pasien_5   Positif                 Ya
#
# Hasil Perhitungan:
# a. Probabilitas pasien Benar sakit jika hasil tesnya POSITIF: 0.48
# b. Probabilitas pasien Tidak sakit jika hasil tesnya NEGATIF: 0.54

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "D:/Downloads/data_pasien2.csv" # Sesuaikan dengan lokasi file Anda
df = pd.read_csv(file_path, encoding = "windows-1252", delimiter=";")
print(df.head())

# a. Probabilitas benar-benar sakit jika hasil tes positif
positif = df[df['Hasil_Tes'] == 'Positif']
sakitPositif = positif[positif['Menderita_Penyakit'] == 'Ya']
probSakitTesPositif = len(sakitPositif) / len(positif)

print(f"a. Probabilitas pasien Benar sakit jika hasil tesnya POSITIF: {probSakitTesPositif:.2f}")
# Out:
#      Pasien Hasil_Tes Menderita_Penyakit
# 0  Pasien_1   Positif                 Ya
# 1  Pasien_2   Positif                 Ya
# 2  Pasien_3   Positif                 Ya
# 3  Pasien_4   Positif                 Ya
# 4  Pasien_5   Positif                 Ya
# a. Probabilitas pasien Benar sakit jika hasil tesnya POSITIF: 0.48

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "D:/Downloads/data_pasien2.csv" # Sesuaikan dengan lokasi file Anda
df = pd.read_csv(file_path, encoding = "windows-1252", delimiter=";")
print(df.head())

# b. Probabilitas tidak sakit jika hasil tes negatif
negatif = df[df['Hasil_Tes'] == 'Negatif']
tidakSakitNegatif = negatif[negatif['Menderita_Penyakit'] == 'Tidak']
tidakSakitTesNegatif = len(tidakSakitNegatif) / len(negatif)

# Tampilkan hasil
print("\nHasil Perhitungan:")
print(f"b. Probabilitas pasien Tidak sakit jika hasil tesnya NEGATIF: {tidakSakitTesNegatif:.2f}")
# Out:
#      Pasien Hasil_Tes Menderita_Penyakit
# 0  Pasien_1   Positif                 Ya
# 1  Pasien_2   Positif                 Ya
# 2  Pasien_3   Positif                 Ya
# 3  Pasien_4   Positif                 Ya
# 4  Pasien_5   Positif                 Ya
#
# Hasil Perhitungan:
# b. Probabilitas pasien Tidak sakit jika hasil tesnya NEGATIF: 0.54

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "D:/Downloads/data_pasien2.csv" # Sesuaikan dengan lokasi file Anda
df = pd.read_csv(file_path, encoding = "windows-1252", delimiter=";")
print(df.head())

# c. Visualisasi distribusi hasil tes dan status penyakit
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Hasil_Tes', hue='Menderita_Penyakit', palette='Set2')
plt.title("Distribusi Hasil Tes dan Status Penyakit")
plt.xlabel("Hasil Tes")
plt.ylabel("Jumlah Pasien")
plt.legend(title="Menderita Penyakit")
plt.grid(True)
plt.show()
# Out:
#      Pasien Hasil_Tes Menderita_Penyakit
# 0  Pasien_1   Positif                 Ya
# 1  Pasien_2   Positif                 Ya
# 2  Pasien_3   Positif                 Ya
# 3  Pasien_4   Positif                 Ya
# 4  Pasien_5   Positif                 Ya
